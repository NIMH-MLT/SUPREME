# %%
from lca_conf import SpotLCA
from RunDEMC.io import load_results
from RunDEMC import Param, dists
from pathlib2 import Path
import pandas as pd
import numpy as np

# %%
# !ls /cogmood/data/derivatives/model_res/
# Out:
# flanker_flkr-11nuj5ty67ojohm39cmzbt23.tgz
# flanker_flkr-2upuqdbw3wdpk3q43x89zysp.tgz
# flanker_flkr-48juqsgxp4m2o7797zvjxln9.tgz
# flanker_flkr-60pixcark57tgonq4abwctvs.tgz
# flanker_flkr-81987885tpc29718g2d8evdm.tgz
# flanker_flkr-h3q7g3g6za07rl9qnhd87hoq.tgz
# flanker_flkr-hvann18ezp9i2kq8bvqivehs.tgz
# flanker_flkr-l8eyqget2wsecwew6bwabn1h.tgz
# flanker_flkr-mglomvxjfi6gya3jmrt7o09w.tgz
# flanker_flkr-mjff7puqxr95bh6d945ru7z2.tgz
# flanker_flkr-ol8u2qd7k4zi7cd0p7idogr4.tgz
# flanker_flkr-p5t6r1pmhqfffx93vv5h8vxc.tgz
# flanker_flkr-q86m1zrqk9q16o5e3dfvb8yx.tgz
# flanker_flkr-qx2vl559ytpgxjwh26fre2fo.tgz
# flanker_flkr-reqevxyh9eqa3jyc8wvucdi2.tgz
# flanker_flkr-s7szmm610ygsyon54c67mlvj.tgz
# flanker_flkr-sz1p1qr5v5saov60ia90oqlh.tgz
# flanker_flkr-v0pbbk0rbplhgr4tsqqrlvzm.tgz
# flanker_flkr-ww2y0qu0joyyxy7lsxirxvm4.tgz
# flanker_flkr-y6d1crfpg0rh1wpohfgi959w.tgz
# flanker_flkr-ycbg09io1hcmzyiosg50hgl8.tgz
# flanker_flkr-ztgwa65cvika8vs9szlbpbnt.tgz

# %%
# !ls /cogmood/data/pilot/to_model
# Out:
# flkr-11nuj5ty67ojohm39cmzbt23.csv  flkr-p5t6r1pmhqfffx93vv5h8vxc.csv
# flkr-2upuqdbw3wdpk3q43x89zysp.csv  flkr-q86m1zrqk9q16o5e3dfvb8yx.csv
# flkr-48juqsgxp4m2o7797zvjxln9.csv  flkr-qx2vl559ytpgxjwh26fre2fo.csv
# flkr-60pixcark57tgonq4abwctvs.csv  flkr-reqevxyh9eqa3jyc8wvucdi2.csv
# flkr-81987885tpc29718g2d8evdm.csv  flkr-s7szmm610ygsyon54c67mlvj.csv
# flkr-h3q7g3g6za07rl9qnhd87hoq.csv  flkr-sz1p1qr5v5saov60ia90oqlh.csv
# flkr-hvann18ezp9i2kq8bvqivehs.csv  flkr-v0pbbk0rbplhgr4tsqqrlvzm.csv
# flkr-l8eyqget2wsecwew6bwabn1h.csv  flkr-ww2y0qu0joyyxy7lsxirxvm4.csv
# flkr-mglomvxjfi6gya3jmrt7o09w.csv  flkr-y6d1crfpg0rh1wpohfgi959w.csv
# flkr-mjff7puqxr95bh6d945ru7z2.csv  flkr-ycbg09io1hcmzyiosg50hgl8.csv
# flkr-ol8u2qd7k4zi7cd0p7idogr4.csv  flkr-ztgwa65cvika8vs9szlbpbnt.csv

# %%
subid = '11nuj5ty67ojohm39cmzbt23'
csv_dir = Path('/cogmood/data/pilot/to_model')
res_dir = Path('/cogmood/data/derivatives/model_res/')

# %%
s = csv_dir / ('flkr-' + subid + '.csv')
log_shift = .05
max_rt = 2
burnin = 400

dat = pd.read_csv(s)
ddat = {}
for c in ['+', '=', '~']:
    ind = (dat.condition == c) & (dat.rt < max_rt)
    d = {'rt':np.log(np.array(dat[ind].rt)+log_shift),
         'resp': np.array(~dat[ind]['correct'], dtype=np.int)}
    ddat[c] = d
    
mdl_tgz = res_dir / ('flanker_flkr-' + subid + '.tgz')
res = load_results(mdl_tgz.as_posix())

# %%
particles = res['particles'][burnin:]
n_chains = particles.shape[1]
n_draws = particles.shape[0]
part_id = np.random.choice(range(n_chains * n_draws))
params = {p:particles[:, :, i].ravel()[part_id] for i,p in enumerate(res['param_names'])}

# %%
params
# Out:
# {'K': 0.005676662663764684,
#  'L': 0.3595527330758844,
#  'alpha': 10.039973279060112,
#  'p': 1.2236403846118284,
#  'r': 0.34431523525235397,
#  'sd0': 1.0826830672409724,
#  't0': 0.37180100536323135,
#  'thresh': 4.467290552322719}
